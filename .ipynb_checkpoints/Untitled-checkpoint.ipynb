# %%
import pandas as pd

# %%
df=pd.read_csv('bike_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                       Name     Price   Location  \
# 0           0    TVS Star City Plus Dual Tone 110cc 2018    35,000  Ahmedabad
# 1           1           Royal Enfield Classic 350cc 2017  1,19,900      Delhi
# 2           2                  Triumph Daytona 675R 2013  6,00,000      Delhi
# 3           3                  TVS Apache RTR 180cc 2017    65,000  Bangalore
# 4           4  Yamaha FZ S V 2.0 150cc-Ltd. Edition 2018    80,000  Bangalore
#
#      Running        Owner
# 0  17,654 Km  First Owner
# 1  11,000 Km  First Owner
# 2     110 Km  First Owner
# 3  16,329 Km  First Owner
# 4  10,000 Km  First Owner

# %%
model=[]
for mod in df.Name:
    
    name=mod.split(' ')
    if 'Honda' and 'CB' in mod:
        model.append(name[0]+' '+name[1]+' '+name[2])
    elif 'FZ' and '2.0' in mod:
         model.append(name[0]+' '+name[1]+' V 2.0')
    elif  'Triumph Street' in mod:
        model.append(name[0]+' '+name[1]+' '+name[2])
    elif 'BMW G 310' in mod:
        model.append(name[0]+' '+name[1]+' '+name[2]+' '+name[3])
    else:
        model.append(name[0]+' '+name[1])

# %%
# model=[]
# for mod in df.Name:
    
#     name=mod.split(' ')
#     if  'Royal' in mod:
#         model.append(name[2])
#     elif 'CB' in mod:
#         model.append(name[1]+' '+name[2])
#     elif 'FZ' and '2.0' in mod:
#         model.append(name[1]+' V 2.0')
#     elif 'Bajaj' and 'Pulsar' in mod:
#         model.append(name[2])
#     else:
#         model.append(name[1])

# %%
df['model']=model

# %%
pd.set_option('display.max_rows',None)
df['Name'].value_counts()
# Out:
# Bajaj Avenger Street 220 2016                                           1896
# Bajaj Pulsar 150cc 2006                                                 1250
# Royal Enfield Classic 350cc 2014                                         679
# Bajaj Dominar 400 ABS 2017                                               672
# Bajaj Avenger 220cc 2014                                                 666
# Honda CB Trigger 150cc 2013                                              642
# Bajaj Pulsar NS200 2013                                                  641
# Yamaha YZF-R15 2.0 150cc 2012                                            639
# Bajaj Pulsar 150cc 2012                                                  639
# Bajaj Avenger 220cc 2012                                                 638
# Bajaj Pulsar 150cc 2008                                                  633
# KTM RC 390cc 2017                                                        633
# ...

# %%
len(df['model'].unique())
# Out:
# 186

# %%
# df.groupby('model').filter(lambda x:l)

# %%
sub_df = df[df.groupby('model').model.transform('count')>10].copy()

# %%
df.shape
# Out:
# (34500, 7)

# %%
sub_df.shape
# Out:
# (34101, 7)

# %%
(sub_df['model'].unique())
# Out:
# array(['TVS Star', 'Royal Enfield', 'TVS Apache', 'Yamaha FZ V 2.0',
#        'Yamaha FZs', 'Honda CB Hornet', 'Hero Splendor',
#        'Yamaha YZF-R15 V 2.0', 'Yamaha FZ25', 'Bajaj Pulsar',
#        'Bajaj Discover', 'Suzuki Gixxer', 'UM Renegade', 'Hero Super',
#        'Honda CBF Stunner', 'Bajaj Avenger', 'KTM RC', 'Honda CB Unicorn',
#        'KTM Duke', 'Honda CBR 150R', 'Mahindra Centuro', 'Hero Hunk',
#        'Yamaha FZ', 'Royal Enfield\u200e', 'Honda CB Shine',
#        'Benelli TNT', 'Honda Dream', 'Hero CD', 'Kawasaki Ninja',
#        'Bajaj Platina', 'Hero Karizma', 'Harley-Davidson Street',
#        'Bajaj CT', 'Yamaha FZ16', 'Bajaj V15', 'Honda CBR 250R',
#        'Hyosung GT650R', 'Yamaha YZF-R15', 'Honda CB ShineSP',
#        'Hero Passion', 'Bajaj Dominar', 'Yamaha Fazer',
#        'Harley-Davidson Iron', 'Hero HF', 'TVS Sport', 'Honda Livo',
#        'Yamaha SZ-RR', 'Yamaha Saluto', 'Hyosung Aquila', 'Bajaj V12',
# ...

# %%
sub_df['model']=sub_df['model'].apply(lambda x: x.replace('Royal Enfield\u200e','Royal Enfield'))

# %%
len(sub_df['model'].unique())
# Out:
# 69

# %%
sub_df['model'].value_counts()
# Out:
# Bajaj Avenger             4859
# Royal Enfield             4253
# Bajaj Pulsar              4232
# Hero Passion              2870
# Yamaha Fazer              1291
# TVS Apache                1062
# KTM RC                     841
# Yamaha YZF-R15 V 2.0       776
# Bajaj Platina              735
# Bajaj Dominar              730
# Harley-Davidson Street     724
# Hero CD                    708
# Honda CB Hornet            705
# Hero CBZ Xtreme            690
# Honda CB Trigger           681
# Yamaha FZ                  670
# Hero Hunk                  660
# Hero Super                 655
# Hyosung GT250R             646
# TVS Victor                 622
# Suzuki Slingshot           617
# Yamaha SZ-RR               613
# Suzuki Zeus                608
# Hero Splendor              431
# Bajaj Discover             398
# KTM Duke                   261
# Honda CB Shine             192
# Suzuki Gixxer              176
# Bajaj V15                  161
# Yamaha YZF-R15             150
# ...

# %%
sub_df[sub_df['model'] == 'BMW G 310 R']
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Price, Location, Running, Owner, model]
# Index: []

# %%
sub_df['model'].shape
# Out:
# (34101,)
